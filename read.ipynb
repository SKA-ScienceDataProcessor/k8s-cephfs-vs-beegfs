# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %pylab
# Out:
# Using matplotlib backend: agg
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
from fiotools import ClatGrid
from pathlib2 import Path

# %%
def clatgrid_helper(name, skip_bs=[128, 256]):
    input_dirs=list(Path('/alaska/bharat/'+name).iterdir())
    output_dir=Path(name)
    grid = ClatGrid(input_dirs, output_dir, 200, force=True, logscale=True, mode='read', skip_bs=skip_bs, plot=False)
    grid.plot_cl()
    grid.plot_bw()
    grid.plot_il(ylim=[2.5,6.5])

# %% [markdown]
# # Random read

# %%
clatgrid_helper('ceph-randread')
# Out:
# Deleting existing output data ceph-randread/read-commit-latency.csv in output directory
# Deleting existing output data ceph-randread/blocksize-vs-bandwidth.png in output directory
# Deleting existing output data ceph-randread/read-bandwidth.csv in output directory
# Deleting existing output data ceph-randread/blocksize-vs-commit-latency.png in output directory
# Deleting existing output data ceph-randread/read-iops-latency.csv in output directory
# Deleting existing output data ceph-randread/commit-latency-freq-dist.png in output directory
# Scanning for fio data in /alaska/bharat/ceph-randread/ceph-randread-vvbzh
# Scanning for fio data in /alaska/bharat/ceph-randread/ceph-randread-9btrm
# Scanning for fio data in /alaska/bharat/ceph-randread/ceph-randread-zf2x7
# Scanning for fio data in /alaska/bharat/ceph-randread/ceph-randread-222wc
# Scanning for fio data in /alaska/bharat/ceph-randread/ceph-randread-x7qbc
# ...

# %%
clatgrid_helper('beegfs-randread')
# Out:
# Deleting existing output data beegfs-randread/read-commit-latency.csv in output directory
# Deleting existing output data beegfs-randread/blocksize-vs-bandwidth.png in output directory
# Deleting existing output data beegfs-randread/read-bandwidth.csv in output directory
# Deleting existing output data beegfs-randread/blocksize-vs-commit-latency.png in output directory
# Deleting existing output data beegfs-randread/read-iops-latency.csv in output directory
# Deleting existing output data beegfs-randread/commit-latency-freq-dist.png in output directory
# Scanning for fio data in /alaska/bharat/beegfs-randread/beegfs-randread-7lst8
# Scanning for fio data in /alaska/bharat/beegfs-randread/beegfs-randread-cll9c
# Scanning for fio data in /alaska/bharat/beegfs-randread/beegfs-randread-kpvrh
# Scanning for fio data in /alaska/bharat/beegfs-randread/beegfs-randread-9bfhm
# Scanning for fio data in /alaska/bharat/beegfs-randread/beegfs-randread-4mbl6
# ...

# %% [markdown]
# # Sequential read

# %%
clatgrid_helper('ceph-read')
# Out:
# Deleting existing output data ceph-read/read-commit-latency.csv in output directory
# Deleting existing output data ceph-read/blocksize-vs-bandwidth.png in output directory
# Deleting existing output data ceph-read/read-bandwidth.csv in output directory
# Deleting existing output data ceph-read/blocksize-vs-commit-latency.png in output directory
# Deleting existing output data ceph-read/read-iops-latency.csv in output directory
# Deleting existing output data ceph-read/commit-latency-freq-dist.png in output directory
# Scanning for fio data in /alaska/bharat/ceph-read/ceph-read-wcvks
# Scanning for fio data in /alaska/bharat/ceph-read/ceph-read-q79kz
# Scanning for fio data in /alaska/bharat/ceph-read/ceph-read-qtqzx
# Scanning for fio data in /alaska/bharat/ceph-read/ceph-read-kzvhn
# Scanning for fio data in /alaska/bharat/ceph-read/ceph-read-j56g8
# Scanning for fio data in /alaska/bharat/ceph-read/ceph-read-f9lkk
# ...

# %%
clatgrid_helper('beegfs-read')
# Out:
# Deleting existing output data beegfs-read/read-commit-latency.csv in output directory
# Deleting existing output data beegfs-read/blocksize-vs-bandwidth.png in output directory
# Deleting existing output data beegfs-read/read-bandwidth.csv in output directory
# Deleting existing output data beegfs-read/blocksize-vs-commit-latency.png in output directory
# Deleting existing output data beegfs-read/read-iops-latency.csv in output directory
# Deleting existing output data beegfs-read/commit-latency-freq-dist.png in output directory
# Scanning for fio data in /alaska/bharat/beegfs-read/beegfs-read-ql6k7
# Scanning for fio data in /alaska/bharat/beegfs-read/beegfs-read-bq6zn
# Scanning for fio data in /alaska/bharat/beegfs-read/beegfs-read-dnwwt
# Scanning for fio data in /alaska/bharat/beegfs-read/beegfs-read-2p8hs
# Scanning for fio data in /alaska/bharat/beegfs-read/beegfs-read-nj7cd
# Scanning for fio data in /alaska/bharat/beegfs-read/beegfs-read-ht9h5
# ...
